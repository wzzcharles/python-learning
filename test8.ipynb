# %% [markdown]
# # 第八次作业：
# #这是一个学习matplotlib的小代码

# %%
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
import numpy as np
# Out:
# C:\Users\go\miniconda3\lib\site-packages\xarray\backends\cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
df = pd.read_excel(r'D:\work\python\test7\rmm.74toRealtime.xlsx')
df
# Out:
#        Unnamed: 0  year  month  day      RMM1      RMM2  phase  amplitude  \
# 0               0  1974      6    1  1.634470  1.203040      5   2.029480
# 1               1  1974      6    2  1.602890  1.015120      5   1.897290
# 2               2  1974      6    3  1.516250  1.085510      5   1.864760
# 3               3  1974      6    4  1.509810  1.035730      5   1.830920
# 4               4  1974      6    5  1.559060  1.305180      5   2.033260
# ...           ...   ...    ...  ...       ...       ...    ...        ...
# 17460       17460  2022      3   21  1.058647 -1.269627      3   1.653084
# 17461       17461  2022      3   22  1.039455 -0.817596      4   1.322471
# 17462       17462  2022      3   23  0.981937 -0.722337      4   1.219004
# 17463       17463  2022      3   24  0.900615 -0.630580      4   1.099426
# 17464       17464  2022      3   25  0.488374 -0.406457      4   0.635386
#
#                            Final_Value
# 0       Final_value:__OLR_&_NCEP_winds
# ...

# %%
#14827行，2015年开始；17018行，2020年结束
data = df.loc[(df['year']>=2015) & (df['year']<=2020)]    #筛选数据：2015-2020年
print(type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Unnamed: 0  year  month  day      RMM1      RMM2  phase  amplitude  \
# 14824       14824  2015      1    1  1.625195  0.142585      5   1.631438
# 14825       14825  2015      1    2  1.248620  0.171765      5   1.260379
# 14826       14826  2015      1    3  1.188003  0.653946      5   1.356096
# 14827       14827  2015      1    4  1.278301  1.070000      5   1.667019
# 14828       14828  2015      1    5  1.610647  1.516953      5   2.212539
# ...           ...   ...    ...  ...       ...       ...    ...        ...
# 17011       17011  2020     12   27 -0.026806  0.064537      7   0.069883
# 17012       17012  2020     12   28  0.059553 -0.097550      3   0.114291
# 17013       17013  2020     12   29  0.216573 -0.201967      4   0.296132
# 17014       17014  2020     12   30  0.195102 -0.357961      3   0.407677
# 17015       17015  2020     12   31  0.061996 -0.530792      3   0.534400
#
#                            Final_Value
# ...

# %%
d1 = []
yr = []
mt = []
mth = range(1,13)
yr = range(2015,2021)
yr[0]
# Out:
# 2015

# %%
for i in yr
    for 
c = data.loc[(data['year']==2015) & (data['month']==1)]
print(c)
a = c['RMM1'].mean()
b = c['RMM2'].mean()

print(a,b)
# Out:
#        Unnamed: 0  year  month  day      RMM1      RMM2  phase  amplitude  \
# 14824       14824  2015      1    1  1.625195  0.142585      5   1.631438
# 14825       14825  2015      1    2  1.248620  0.171765      5   1.260379
# 14826       14826  2015      1    3  1.188003  0.653946      5   1.356096
# 14827       14827  2015      1    4  1.278301  1.070000      5   1.667019
# 14828       14828  2015      1    5  1.610647  1.516953      5   2.212539
# 14829       14829  2015      1    6  1.854545  1.434372      5   2.344517
# 14830       14830  2015      1    7  2.025259  1.546518      5   2.548214
# 14831       14831  2015      1    8  1.851416  1.968979      6   2.702706
# 14832       14832  2015      1    9  1.816403  2.332186      6   2.956081
# 14833       14833  2015      1   10  1.558206  2.378762      6   2.843680
# 14834       14834  2015      1   11  1.137547  2.434400      6   2.687065
# 14835       14835  2015      1   12  0.547032  2.053315      6   2.124934
# ...

# %%
rm = {}
rm['rm1'] = data['RMM1']
rm['rm2'] = data['RMM2']
print(type(rm['rm1']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
fig, ax = plt.subplots()    #建立坐标轴
ax.set_xlabel()
ax.set_ylabel()
ax.set_title()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8420/3385829708.py in <module>
#       1 fig, ax = plt.subplots()    #建立坐标轴
# ----> 2 ax.set_xlabel()
#       3 ax.set_ylabel()
#       4 ax.set_title()
#
# TypeError: set_xlabel() missing 1 required positional argument: 'xlabel'
